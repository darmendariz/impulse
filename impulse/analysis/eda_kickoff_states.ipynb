# %% [markdown]
# # Explore kickoff frames to inform replay segmentation strategy

# %% [markdown]
# (need to add some words here about why replay segmentation is useful/necessary)

# %%
# Imports
from impulse import ReplayDataset
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd

# %%
project_root = Path('/Users/david/dev/impulse')
data_dir = project_root / 'replays' / 'parsed'
db_path = project_root / 'impulse.db'

replays = ReplayDataset(db_path=str(db_path), data_dir=str(data_dir))

# %% [markdown]
# First, let's look at the first 20 frames of every replay in our dataset.

# %%
frames_list = []
for replay in replays:
    frames_list.append(replay.frames.iloc[:20][['Ball - position x', 'Ball - position y', 'Ball - position z', 'Ball - linear velocity x', 'Ball - linear velocity y', 'Ball - linear velocity z']])

# %%
all_frames = pd.concat(frames_list)
all_frames
# Out:
#     Ball - position x  Ball - position y  Ball - position z  \
# 0          -65.029999         -51.560001         104.410004
# 1         -201.100006         -62.099998         112.190002
# 2         -314.170013         -70.800003         113.690002
# 3         -471.980011         -82.980003         108.230003
# 4         -584.349976         -91.680000          98.930000
# ..                ...                ...                ...
# 15        3048.169922        1532.510010         836.900024
# 16        3308.000000        1568.989990         861.640015
# 17        3567.040039        1605.349976         879.809998
# 18        3782.300049        1635.550049         889.950012
# 19        3994.629883        1669.880005         896.070007
#
#     Ball - linear velocity x  Ball - linear velocity y  \
# 0               -1362.949951               -105.309998
# 1               -1358.750000               -104.949997
# 2               -1355.250000               -104.650002
# 3               -1350.349976               -104.230003
# 4               -1346.849976               -103.930000
# ..                       ...                       ...
# 15               2602.610107                365.420013
# 16               2594.689941                364.220001
# 17               2586.770020                363.019989
# 18               2580.169922                362.019989
# 19              -1543.349976                144.309998
#
#     Ball - linear velocity z
# 0                 113.160004
# 1                  47.849998
# 2                  -6.390000
# 3                 -82.019997
# 4                -135.880005
# ..                       ...
# 15                283.100006
# 16                217.279999
# 17                151.669998
# 18                 97.139999
# 19                 24.850000
#
# [3840 rows x 6 columns]

# %% [markdown]
# It appears that either the parser (subtr-actor) itself or the sub-sampling of the raw frames is cutting off the very first initial kickoff setup state at the start of most games. Only one game above displays the pattern of having `0.0` in the `Ball - position x`, `Ball - position y`, and ball linear velocity columns in its first 20 frames that indicate an initial kickoff setup state, while the rest have non-zero values in these columns in the first 20 rows.
#
# This should be fine for segmenting replays into individual generations of play, however, as long as kickoff reset events are reliably detectable mid-game. If so, then we can just segment from the start of the array to the first kickoff reset, then from the first kickoff reset to the second kickoff reset, ..., then finally from the last kickoff reset to the end of the array.
#
# Let's check a handful of replays to verify that they follow this pattern.

# %% [markdown]
# To be extra careful, let's make sure to check games played on different maps to be sure that origin coordinates and kickoff configurations do not differ from map to map.
#
# We start by creating a dictionary mapping each `replay_id` to the `map` name that the corresponding game was played on:

# %%
replay_id_to_map = {replay.replay_id: replay.map for replay in replays}
replay_id_to_map
# Out:
# {'0328fc07-13fb-4cb6-9a86-7d608196ddbd': 'NeoTokyo_Standard_P',
#  '960a9f35-821d-4c43-8c94-2d52697ecdeb': 'Underwater_GRS_P',
#  '3b823061-0ae0-486a-933a-dfe229c17c3d': 'UtopiaStadium_Dusk_P',
#  '960b8433-fafd-4e0d-9370-571190e44dae': 'Stadium_P',
#  '1e62a0d0-6c47-4b12-a784-b60d9b883632': 'CHN_Stadium_P',
#  'eacc54f9-06cf-49c0-a9b1-238aed98eca3': 'EuroStadium_Night_P',
#  'f597731e-4fd0-445d-a00c-03f867508bc3': 'cs_p',
#  'd1b3c0c8-466e-4855-89b5-793b3a127ca5': 'NeoTokyo_Standard_P',
#  '583e67ad-7b6f-4163-9cf1-81b0d21accf8': 'Underwater_GRS_P',
#  '3037096d-17ff-41a5-83d9-ce0cdd271740': 'UtopiaStadium_Dusk_P',
#  'b3c8af60-0e68-4ab8-af8e-0b72b60b4e68': 'Stadium_P',
#  '4f08f62b-69cc-4452-b26f-2fe437f50ab7': 'CHN_Stadium_P',
#  '14ddbdfb-2d50-4da7-bfa2-9e26004b51fd': 'EuroStadium_Night_P',
#  '7582bdce-4d45-43c7-9370-da766b1bad3a': 'cs_p',
#  '7653defe-924e-45be-a581-39f15f498301': 'NeoTokyo_Standard_P',
#  '373599ae-9f3d-4432-adbf-7592a04edcd8': 'Underwater_GRS_P',
#  'e23bd48e-260b-4d4c-975c-0f624ec19ac3': 'UtopiaStadium_Dusk_P',
#  '13decc4a-cd02-4f27-b745-ddd0f31b749d': 'Stadium_P',
#  '75a3ed3a-5641-4e5b-9bac-d645ff456d92': 'CHN_Stadium_P',
#  '3fa21d60-ea28-40ab-bc08-007fd1b4bbe7': 'EuroStadium_Night_P',
#  'e287ba49-b1d9-44ac-93ea-16df42bac3fb': 'NeoTokyo_Standard_P',
#  '7a74acad-5a28-40c3-9fcb-b01a3bd12e4a': 'Underwater_GRS_P',
#  'a4d697a7-9f29-4b5e-84ce-796e477d737e': 'UtopiaStadium_Dusk_P',
#  'bfdc9a8c-318c-4b58-a821-573db5b18202': 'Stadium_P',
#  'cfefb156-8af0-4970-bc8e-995ed5fb33ff': 'CHN_Stadium_P',
#  'cd2aa4a9-a72f-4905-860b-ad358e4de7b9': 'EuroStadium_Night_P',
#  '44a1d0bf-c067-4132-aebf-c9726ce2809e': 'cs_p',
#  '3f257d2f-f7b6-45d4-979a-5e8e61186dd5': 'NeoTokyo_Standard_P',
#  'b911b75f-7cd3-4625-b545-687153786631': 'Underwater_GRS_P',
#  '164bf2ab-7780-410f-988f-2567fc33f051': 'UtopiaStadium_Dusk_P',
#  '576ef850-82df-4fb8-b5cf-4eea13bcbcac': 'Stadium_P',
#  '09d90aac-529f-46a7-9761-5eb58ed1fb5c': 'CHN_Stadium_P',
#  '9f7b20e9-a2d7-4578-b69d-3c3c480efd00': 'EuroStadium_Night_P',
#  'bfa8bcd8-5be8-4960-b8fb-6367cb38bbd9': 'cs_p',
#  '490c1d1d-0547-4ccb-8589-fc3e8b4c387e': 'NeoTokyo_Standard_P',
#  '32beb85e-0d3b-4b34-9010-72d2ff3321ba': 'Underwater_GRS_P',
#  'fddf1a4a-3400-45a5-a32c-999e0b12d719': 'UtopiaStadium_Dusk_P',
#  'dbbc96da-8eee-43c6-adef-e7f69dbaae34': 'Stadium_P',
#  '8323a435-e2a6-4e88-8bfa-ed4baa17b105': 'CHN_Stadium_P',
#  '26f6b861-7bf8-4606-9e41-630495178102': 'EuroStadium_Night_P',
#  'e1576578-ccb6-4848-ac41-a4e55313d836': 'Underwater_GRS_P',
#  '586021fd-0c66-4807-b514-3c636626dc50': 'UtopiaStadium_Dusk_P',
#  'c7dbaf99-df84-4319-bdfe-ad1c0fdb35d4': 'Stadium_P',
#  '887f2cef-2cb2-4749-9641-5bc24e2d3b71': 'CHN_Stadium_P',
#  '0c5ee496-bbc0-44b0-9d6b-1fae67fa12fe': 'EuroStadium_Night_P',
#  'cb2c9df7-ca13-4e2c-979e-e61b9c6f4b96': 'cs_p',
#  '85e5af77-0010-4e68-8cbd-24a85a830274': 'NeoTokyo_Standard_P',
#  'c3ddc3e1-838b-4da3-bf8c-6cc2f49f355e': 'Underwater_GRS_P',
#  'cbfc13a6-bbe2-4798-9d01-c161d38a8a56': 'UtopiaStadium_Dusk_P',
#  '885a04c6-fec7-4aaa-8ec6-0325cb1a0462': 'Stadium_P',
#  '7a1a62ae-ecdf-4a5e-952a-14992cc8e9a3': 'CHN_Stadium_P',
#  'a393830f-58a3-4764-96c1-5be400e76f56': 'EuroStadium_Night_P',
#  '7b80f0e4-a8e7-4c2d-8c55-c9f266da2403': 'NeoTokyo_Standard_P',
#  'f912a587-1bb9-46a8-b0bc-23d248e4fe09': 'Underwater_GRS_P',
#  'eb59ac49-3c6b-4c4a-8a4c-ba44a4cdd2f1': 'UtopiaStadium_Dusk_P',
#  '0f5bbc53-7eff-41f0-8c91-0ecae6fe3555': 'Stadium_P',
#  '42404224-f575-4282-8f35-cc09914aef83': 'CHN_Stadium_P',
#  'e68d1fa8-c755-4ee7-ae24-879e83d1f9e2': 'EuroStadium_Night_P',
#  '5628ffa1-d532-4c6c-aec0-d7a7c9ebe3d4': 'cs_p',
#  'aa79d88a-c430-4933-97b4-d945466fa7c6': 'UtopiaStadium_Dusk_P',
#  '448d4138-53ef-408f-87cf-a1e022ad702a': 'Stadium_P',
#  '779bd483-a3f9-4b9e-95c2-512401b75b30': 'CHN_Stadium_P',
#  '2d30336d-225c-4ada-9c4e-2075f8e67f94': 'EuroStadium_Night_P',
#  'bc6d3b47-3908-42c4-a697-e6ac34757c39': 'UtopiaStadium_Dusk_P',
#  '0466e9a5-286e-4688-bed2-50de4521e2d8': 'Stadium_P',
#  'db3e9b3d-d818-4302-b01a-4baaaa657bd7': 'CHN_Stadium_P',
#  'c08d92f8-187b-42a7-8023-e079b1a80e43': 'EuroStadium_Night_P',
#  'ff86fa37-1b09-4346-82f4-795d92e2e061': 'Stadium_P',
#  '3757e7a8-9558-4c53-a707-f78fa03b6525': 'CHN_Stadium_P',
#  '25ea48bb-d514-4944-979b-7ca624d77f97': 'EuroStadium_Night_P',
#  '2f00d90d-5b80-4a7b-8f2c-367ee2725320': 'UtopiaStadium_Dusk_P',
#  'e52f1bb1-6791-428a-b461-0ad399dba7cf': 'Stadium_P',
#  'a542727c-f923-4d88-8e09-66d59beedb39': 'CHN_Stadium_P',
#  'f6457f18-6e90-42e1-b4de-d115242ff4bb': 'EuroStadium_Night_P',
#  '4631f924-aa6f-40b5-b166-7a2b4abae3d0': 'Stadium_P',
#  '12a5fe7d-8e30-4c1d-89d2-a8f233bc6ed9': 'CHN_Stadium_P',
#  'a799ee86-e047-4087-af3b-3dcc855ec6f7': 'EuroStadium_Night_P',
#  '18686445-06ae-4e4b-aaf9-ba638c3694e1': 'UtopiaStadium_Dusk_P',
#  '969e30ca-9dc6-41de-9ad2-6906ff800171': 'Stadium_P',
#  'a59ae528-33dd-4214-a00e-6a4dc6c7c7b3': 'CHN_Stadium_P',
#  'bdb149d8-9d68-4cd9-8fee-3e730cc118a7': 'EuroStadium_Night_P',
#  '83c9fd34-ff60-4338-a874-9bd9cf4b35b4': 'UtopiaStadium_Dusk_P',
#  '07d77edc-5396-4857-bcb3-8fd520f83e9b': 'Stadium_P',
#  '8974485a-994a-441a-a70f-bf0c65bc0bb5': 'CHN_Stadium_P',
#  '7f7fd5ca-e21b-4b71-a256-bd7c4cdae46f': 'EuroStadium_Night_P',
#  '67403856-e654-4bfd-8751-8a8ae9740d34': 'cs_p',
#  'f74b1fa5-a20e-4621-829e-03c536e35ffc': 'UtopiaStadium_Dusk_P',
#  '3dc4ade5-c401-4e78-bacf-5398810ee1a6': 'Stadium_P',
#  'e1094f2a-f5df-4267-993f-c7d221a55be2': 'CHN_Stadium_P',
#  '4629d801-8028-4f9b-8452-8146f0d250b5': 'EuroStadium_Night_P',
#  '51d994bb-dfe3-4d75-b7c5-9bc425d56a80': 'UtopiaStadium_Dusk_P',
#  '7c80c9fa-dee6-4f92-9000-2ba5a639b96c': 'Stadium_P',
#  'd06ce16e-a69a-4410-bfb8-554aa2a9f6da': 'CHN_Stadium_P',
#  'f8bbaa0a-8a2f-444e-adad-fba3fc69675a': 'EuroStadium_Night_P',
#  '11544962-34ca-427c-89d7-a39c914ce506': 'Stadium_P',
#  '425ecf29-a5b7-4141-b7ad-2470daa1ab60': 'CHN_Stadium_P',
#  '91c07960-a340-4b7a-ad9a-b481d869a634': 'EuroStadium_Night_P',
#  '6eece9ae-495c-44a8-afdf-da718ee86773': 'UtopiaStadium_Dusk_P',
#  'ef403ddf-76ef-4d5c-8e97-364cf2f1a715': 'Stadium_P',
#  '2b6f4dcf-3f91-43b7-a0ef-84b848cd93d6': 'CHN_Stadium_P',
#  '8ca4206c-8a32-4c76-9483-b1013a3f11d1': 'EuroStadium_Night_P',
#  'f5dc9278-2eba-43c0-9a9d-69edcf22463f': 'Stadium_P',
#  'b3150cb3-c5de-48ef-aeb6-11df0f6502f2': 'CHN_Stadium_P',
#  '34573049-895b-43f3-b553-97fb70018539': 'EuroStadium_Night_P',
#  '60d78c56-7b0c-4337-97f3-22d3e4010ba2': 'UtopiaStadium_Dusk_P',
#  'd754dfcd-05c8-41a3-a45d-b3411afec128': 'Stadium_P',
#  'b5b98ef8-04fc-47fa-bbf3-24082b5e246d': 'CHN_Stadium_P',
#  'f3fd416f-3649-4aba-934f-249985881aa1': 'EuroStadium_Night_P',
#  '6bd0c1f6-6984-4a57-88ea-ab7cb49b6af4': 'cs_p',
#  '89e8f010-5135-473c-8b33-c2b940129046': 'UtopiaStadium_Dusk_P',
#  'a63718e6-fe99-4cc5-89ef-69b03cc77b24': 'Stadium_P',
#  'cc31bab6-2db1-4ac3-a601-128fdfe403e6': 'CHN_Stadium_P',
#  '4f3afebe-6bb2-448b-b764-5e98d4ad932a': 'EuroStadium_Night_P',
#  'd4b3fb2b-4b04-466b-b35a-f8cde83f9f88': 'UtopiaStadium_Dusk_P',
#  'b255af08-c1d3-4f95-9bf8-4b430be52986': 'Stadium_P',
#  '25ca610f-fcfe-4c4a-a41f-f646daa79e49': 'CHN_Stadium_P',
#  'c4d6f6ed-ff57-40d6-83a3-871efa688fae': 'EuroStadium_Night_P',
#  'b5eaa00f-fbb3-4397-a912-5e7a852c7582': 'UtopiaStadium_Dusk_P',
#  '367cbb88-7144-4b01-b977-c32164e59e4f': 'Stadium_P',
#  'ae40c075-113b-46d8-af5e-4bddeeba2a6e': 'CHN_Stadium_P',
#  'eb269f59-8108-44e3-9e2b-72ddec29cd76': 'EuroStadium_Night_P',
#  'b2909c11-55ce-4c0c-80f4-567266c31d92': 'Stadium_P',
#  '96ffc0e7-b50a-4992-8215-792adcc712c1': 'CHN_Stadium_P',
#  '16749bf5-b335-455e-bd64-22cd1db6a6b4': 'EuroStadium_Night_P',
#  'a044e9c6-a57c-4d26-997e-84514752b597': 'UtopiaStadium_Dusk_P',
#  '73e0d71a-4325-4461-92a8-487445b75cc4': 'Stadium_P',
#  'd5e67ab6-d954-4e42-8566-0c23a75bed12': 'CHN_Stadium_P',
#  '828eef23-1658-4861-a9c5-c9ed1aecf8fe': 'EuroStadium_Night_P',
#  'b18501a9-d241-4e51-8f65-d6b72ccbc1c0': 'UtopiaStadium_Dusk_P',
#  '9578a120-7c1e-4ecc-be47-738352b90d6d': 'Stadium_P',
#  'f5bc3ca9-9d0c-4f8b-900a-588bea99ee45': 'CHN_Stadium_P',
#  '8ff1196c-7005-44c4-9f99-9dd3cbe476af': 'EuroStadium_Night_P',
#  '26860f05-b7de-4949-94c3-f749d3bc457c': 'Stadium_P',
#  '4a60e987-d253-464e-ad9d-1319b34ae314': 'CHN_Stadium_P',
#  'f0de6852-9d66-4df6-9a07-78e6724afd94': 'EuroStadium_Night_P',
#  '76e610ac-47f4-428f-ab49-bc4ed8d13a70': 'cs_p',
#  'f0efb773-874d-4253-bc34-4f3c7f45154e': 'UtopiaStadium_Dusk_P',
#  '8296682b-69d2-441c-9524-32989fa465e3': 'Stadium_P',
#  'ffbd156f-1110-4c31-9695-11a8ac5df550': 'CHN_Stadium_P',
#  '40cbf724-2b19-4307-bd8b-0b7355808ea6': 'EuroStadium_Night_P',
#  '06936c76-2494-4930-b2e0-2d6222dea7b8': 'Stadium_P',
#  'd17a4f82-92c1-4a50-8731-b8c6cef9e27c': 'CHN_Stadium_P',
#  '67351ef9-3f0e-42ac-800e-1eefdbafb688': 'EuroStadium_Night_P',
#  '00779b61-b28d-412f-b50b-546fb6cc6477': 'Stadium_P',
#  'b5e43b65-aafa-44d4-a199-e7eeb4c24625': 'CHN_Stadium_P',
#  '2ccde8c3-c118-443c-a6a1-9424c3baafc0': 'EuroStadium_Night_P',
#  '0733c3c6-08b0-47ba-8e5f-a27ab5517441': 'cs_p',
#  '186752c5-2adf-4a89-a9c4-333e967d7df9': 'UtopiaStadium_Dusk_P',
#  '6a859845-1cf8-4a80-ae92-01d5f85e6d88': 'Stadium_P',
#  '5326a7b6-5c7d-454b-b809-d23de48873b2': 'CHN_Stadium_P',
#  'f666f10e-7c7c-4b6f-a21f-fdca68175eb7': 'EuroStadium_Night_P',
#  '556f0177-33b7-4ef4-8873-1551c89c9e7b': 'UtopiaStadium_Dusk_P',
#  'f747412b-df2d-411f-8232-3942f0f810d8': 'Stadium_P',
#  '23dcd3c6-8633-4eb3-a423-77fd9d849e89': 'CHN_Stadium_P',
#  'fe71cb21-4af5-4eb9-a3d0-78529e5b19fe': 'EuroStadium_Night_P',
#  'c655459d-7ada-4029-9f35-3bb45920d649': 'UtopiaStadium_Dusk_P',
#  'f698fa4a-55e8-47bf-bdad-91f7b064b5f2': 'Stadium_P',
#  '615576a5-b22d-4090-b8c7-98cee2084900': 'CHN_Stadium_P',
#  '0931d6c8-1f42-4f81-9c30-e954b213dff4': 'EuroStadium_Night_P',
#  '50d5fdc7-4efd-4cb3-9a90-b400cb5a9048': 'UtopiaStadium_Dusk_P',
#  '9b3815c6-b8f6-4e44-ab04-6a74017ab52e': 'Stadium_P',
#  'c955b626-cd98-4a80-bbc5-755996292d4d': 'CHN_Stadium_P',
#  '3464f57d-71aa-4eb5-a381-ea7553b3b81b': 'EuroStadium_Night_P',
#  'b0c29a37-4cbc-4b28-83a2-41a4102b0840': 'Stadium_P',
#  'd62b0ec5-051c-4586-bb81-e9ea00ed11f6': 'CHN_Stadium_P',
#  '52bf3a0a-2f1f-439d-b906-d91925463c52': 'EuroStadium_Night_P',
#  'ca578364-2bbb-4398-b5ed-737fd85105fa': 'UtopiaStadium_Dusk_P',
#  '40598b8b-331b-4a8d-93b0-5444cadab478': 'Stadium_P',
#  'bf5f9568-1d42-47a6-af4f-88d58b6711c4': 'CHN_Stadium_P',
#  'f44dde80-e058-47eb-9df6-19af401b122d': 'EuroStadium_Night_P',
#  'f140f2e5-96db-41b4-b1c3-bd011574bf38': 'Stadium_P',
#  '62f7958a-478d-4b9e-89a0-cdfb214bb407': 'CHN_Stadium_P',
#  'd5a20790-eb53-46f8-aac0-1482465d8fc7': 'EuroStadium_Night_P',
#  'de18cec5-b033-48f4-b163-57e4bc2619d4': 'UtopiaStadium_Dusk_P',
#  'b6f91c40-7e99-455b-9512-986d8ba9215a': 'Stadium_P',
#  '16a6fe12-2f88-4eef-af3e-293d40c3880e': 'CHN_Stadium_P',
#  '8f09107d-4fdc-401a-950a-3b8ab6cf4c82': 'EuroStadium_Night_P',
#  'f1428016-6ad5-4f2f-bab9-502de8f9c1d0': 'UtopiaStadium_Dusk_P',
#  '1e6c5469-259c-41df-bc00-b77008dd7381': 'Stadium_P',
#  '59aab432-582c-473e-94f4-d69cdb9e4a17': 'CHN_Stadium_P',
#  '928b8dd4-b92b-49d4-b4cc-b4e49f0145d0': 'EuroStadium_Night_P',
#  '3b5016e4-9386-4f2a-8620-7506ac55b02f': 'Stadium_P',
#  '75a18911-7d71-475a-963d-eda9c0094f1f': 'CHN_Stadium_P',
#  '4d6e1dd1-d996-4750-8b41-627707d70577': 'EuroStadium_Night_P',
#  '9b198ea7-ecd9-443e-abb1-4b3b8cfc5c6f': 'Stadium_P',
#  '50a65913-243a-4cf3-a7e5-d3834ddcddeb': 'CHN_Stadium_P',
#  '9bb8a497-7026-47da-b89c-e46cb2bda4b7': 'EuroStadium_Night_P',
#  'd060beee-e1f3-4447-8d91-d5f9a04732a0': 'Stadium_P',
#  '85c5aead-2fc0-46f7-9c12-fef314f299a3': 'CHN_Stadium_P',
#  '03adfea8-4b43-4af5-9c8e-1e4b405f2ddd': 'EuroStadium_Night_P',
#  '4191381f-092a-4929-a2af-d553edd81484': 'CHN_Stadium_P',
#  '69ee1052-d39f-4aab-921e-2fefb529962d': 'EuroStadium_Night_P'}

# %% [markdown]
# For our purposes, we want a dictionary that connects each unique `map` name to all the `replay_id`s played on that map, so that for each different map we can randomly select a replay played on that map.

# %%
map_set = set(replay_id_to_map.values())
map_set
# Out:
# {'CHN_Stadium_P',
#  'EuroStadium_Night_P',
#  'NeoTokyo_Standard_P',
#  'Stadium_P',
#  'Underwater_GRS_P',
#  'UtopiaStadium_Dusk_P',
#  'cs_p'}

# %%
len(map_set)
# Out:
# 7

# %% [markdown]
# The fact that we have seven different options for maps makes sense given the fact that our replays are RLCS games played in best-of-seven series (at most), and the order of maps in a BO7 is the same from series to series.

# %%
map_to_replay_ids = {map_name: [replay_id for replay_id, map in replay_id_to_map.items() if map == map_name] for map_name in map_set}
map_to_replay_ids
# Out:
# {'Underwater_GRS_P': ['960a9f35-821d-4c43-8c94-2d52697ecdeb',
#   '583e67ad-7b6f-4163-9cf1-81b0d21accf8',
#   '373599ae-9f3d-4432-adbf-7592a04edcd8',
#   '7a74acad-5a28-40c3-9fcb-b01a3bd12e4a',
#   'b911b75f-7cd3-4625-b545-687153786631',
#   '32beb85e-0d3b-4b34-9010-72d2ff3321ba',
#   'e1576578-ccb6-4848-ac41-a4e55313d836',
#   'c3ddc3e1-838b-4da3-bf8c-6cc2f49f355e',
#   'f912a587-1bb9-46a8-b0bc-23d248e4fe09'],
#  'cs_p': ['f597731e-4fd0-445d-a00c-03f867508bc3',
#   '7582bdce-4d45-43c7-9370-da766b1bad3a',
#   '44a1d0bf-c067-4132-aebf-c9726ce2809e',
#   'bfa8bcd8-5be8-4960-b8fb-6367cb38bbd9',
#   'cb2c9df7-ca13-4e2c-979e-e61b9c6f4b96',
#   '5628ffa1-d532-4c6c-aec0-d7a7c9ebe3d4',
#   '67403856-e654-4bfd-8751-8a8ae9740d34',
#   '6bd0c1f6-6984-4a57-88ea-ab7cb49b6af4',
#   '76e610ac-47f4-428f-ab49-bc4ed8d13a70',
#   '0733c3c6-08b0-47ba-8e5f-a27ab5517441'],
#  'NeoTokyo_Standard_P': ['0328fc07-13fb-4cb6-9a86-7d608196ddbd',
#   'd1b3c0c8-466e-4855-89b5-793b3a127ca5',
#   '7653defe-924e-45be-a581-39f15f498301',
#   'e287ba49-b1d9-44ac-93ea-16df42bac3fb',
#   '3f257d2f-f7b6-45d4-979a-5e8e61186dd5',
#   '490c1d1d-0547-4ccb-8589-fc3e8b4c387e',
#   '85e5af77-0010-4e68-8cbd-24a85a830274',
#   '7b80f0e4-a8e7-4c2d-8c55-c9f266da2403'],
#  'UtopiaStadium_Dusk_P': ['3b823061-0ae0-486a-933a-dfe229c17c3d',
#   '3037096d-17ff-41a5-83d9-ce0cdd271740',
#   'e23bd48e-260b-4d4c-975c-0f624ec19ac3',
#   'a4d697a7-9f29-4b5e-84ce-796e477d737e',
#   '164bf2ab-7780-410f-988f-2567fc33f051',
#   'fddf1a4a-3400-45a5-a32c-999e0b12d719',
#   '586021fd-0c66-4807-b514-3c636626dc50',
#   'cbfc13a6-bbe2-4798-9d01-c161d38a8a56',
#   'eb59ac49-3c6b-4c4a-8a4c-ba44a4cdd2f1',
#   'aa79d88a-c430-4933-97b4-d945466fa7c6',
#   'bc6d3b47-3908-42c4-a697-e6ac34757c39',
#   '2f00d90d-5b80-4a7b-8f2c-367ee2725320',
#   '18686445-06ae-4e4b-aaf9-ba638c3694e1',
#   '83c9fd34-ff60-4338-a874-9bd9cf4b35b4',
#   'f74b1fa5-a20e-4621-829e-03c536e35ffc',
#   '51d994bb-dfe3-4d75-b7c5-9bc425d56a80',
#   '6eece9ae-495c-44a8-afdf-da718ee86773',
#   '60d78c56-7b0c-4337-97f3-22d3e4010ba2',
#   '89e8f010-5135-473c-8b33-c2b940129046',
#   'd4b3fb2b-4b04-466b-b35a-f8cde83f9f88',
#   'b5eaa00f-fbb3-4397-a912-5e7a852c7582',
#   'a044e9c6-a57c-4d26-997e-84514752b597',
#   'b18501a9-d241-4e51-8f65-d6b72ccbc1c0',
#   'f0efb773-874d-4253-bc34-4f3c7f45154e',
#   '186752c5-2adf-4a89-a9c4-333e967d7df9',
#   '556f0177-33b7-4ef4-8873-1551c89c9e7b',
#   'c655459d-7ada-4029-9f35-3bb45920d649',
#   '50d5fdc7-4efd-4cb3-9a90-b400cb5a9048',
#   'ca578364-2bbb-4398-b5ed-737fd85105fa',
#   'de18cec5-b033-48f4-b163-57e4bc2619d4',
#   'f1428016-6ad5-4f2f-bab9-502de8f9c1d0'],
#  'Stadium_P': ['960b8433-fafd-4e0d-9370-571190e44dae',
#   'b3c8af60-0e68-4ab8-af8e-0b72b60b4e68',
#   '13decc4a-cd02-4f27-b745-ddd0f31b749d',
#   'bfdc9a8c-318c-4b58-a821-573db5b18202',
#   '576ef850-82df-4fb8-b5cf-4eea13bcbcac',
#   'dbbc96da-8eee-43c6-adef-e7f69dbaae34',
#   'c7dbaf99-df84-4319-bdfe-ad1c0fdb35d4',
#   '885a04c6-fec7-4aaa-8ec6-0325cb1a0462',
#   '0f5bbc53-7eff-41f0-8c91-0ecae6fe3555',
#   '448d4138-53ef-408f-87cf-a1e022ad702a',
#   '0466e9a5-286e-4688-bed2-50de4521e2d8',
#   'ff86fa37-1b09-4346-82f4-795d92e2e061',
#   'e52f1bb1-6791-428a-b461-0ad399dba7cf',
#   '4631f924-aa6f-40b5-b166-7a2b4abae3d0',
#   '969e30ca-9dc6-41de-9ad2-6906ff800171',
#   '07d77edc-5396-4857-bcb3-8fd520f83e9b',
#   '3dc4ade5-c401-4e78-bacf-5398810ee1a6',
#   '7c80c9fa-dee6-4f92-9000-2ba5a639b96c',
#   '11544962-34ca-427c-89d7-a39c914ce506',
#   'ef403ddf-76ef-4d5c-8e97-364cf2f1a715',
#   'f5dc9278-2eba-43c0-9a9d-69edcf22463f',
#   'd754dfcd-05c8-41a3-a45d-b3411afec128',
#   'a63718e6-fe99-4cc5-89ef-69b03cc77b24',
#   'b255af08-c1d3-4f95-9bf8-4b430be52986',
#   '367cbb88-7144-4b01-b977-c32164e59e4f',
#   'b2909c11-55ce-4c0c-80f4-567266c31d92',
#   '73e0d71a-4325-4461-92a8-487445b75cc4',
#   '9578a120-7c1e-4ecc-be47-738352b90d6d',
#   '26860f05-b7de-4949-94c3-f749d3bc457c',
#   '8296682b-69d2-441c-9524-32989fa465e3',
#   '06936c76-2494-4930-b2e0-2d6222dea7b8',
#   '00779b61-b28d-412f-b50b-546fb6cc6477',
#   '6a859845-1cf8-4a80-ae92-01d5f85e6d88',
#   'f747412b-df2d-411f-8232-3942f0f810d8',
#   'f698fa4a-55e8-47bf-bdad-91f7b064b5f2',
#   '9b3815c6-b8f6-4e44-ab04-6a74017ab52e',
#   'b0c29a37-4cbc-4b28-83a2-41a4102b0840',
#   '40598b8b-331b-4a8d-93b0-5444cadab478',
#   'f140f2e5-96db-41b4-b1c3-bd011574bf38',
#   'b6f91c40-7e99-455b-9512-986d8ba9215a',
#   '1e6c5469-259c-41df-bc00-b77008dd7381',
#   '3b5016e4-9386-4f2a-8620-7506ac55b02f',
#   '9b198ea7-ecd9-443e-abb1-4b3b8cfc5c6f',
#   'd060beee-e1f3-4447-8d91-d5f9a04732a0'],
#  'CHN_Stadium_P': ['1e62a0d0-6c47-4b12-a784-b60d9b883632',
#   '4f08f62b-69cc-4452-b26f-2fe437f50ab7',
#   '75a3ed3a-5641-4e5b-9bac-d645ff456d92',
#   'cfefb156-8af0-4970-bc8e-995ed5fb33ff',
#   '09d90aac-529f-46a7-9761-5eb58ed1fb5c',
#   '8323a435-e2a6-4e88-8bfa-ed4baa17b105',
#   '887f2cef-2cb2-4749-9641-5bc24e2d3b71',
#   '7a1a62ae-ecdf-4a5e-952a-14992cc8e9a3',
#   '42404224-f575-4282-8f35-cc09914aef83',
#   '779bd483-a3f9-4b9e-95c2-512401b75b30',
#   'db3e9b3d-d818-4302-b01a-4baaaa657bd7',
#   '3757e7a8-9558-4c53-a707-f78fa03b6525',
#   'a542727c-f923-4d88-8e09-66d59beedb39',
#   '12a5fe7d-8e30-4c1d-89d2-a8f233bc6ed9',
#   'a59ae528-33dd-4214-a00e-6a4dc6c7c7b3',
#   '8974485a-994a-441a-a70f-bf0c65bc0bb5',
#   'e1094f2a-f5df-4267-993f-c7d221a55be2',
#   'd06ce16e-a69a-4410-bfb8-554aa2a9f6da',
#   '425ecf29-a5b7-4141-b7ad-2470daa1ab60',
#   '2b6f4dcf-3f91-43b7-a0ef-84b848cd93d6',
#   'b3150cb3-c5de-48ef-aeb6-11df0f6502f2',
#   'b5b98ef8-04fc-47fa-bbf3-24082b5e246d',
#   'cc31bab6-2db1-4ac3-a601-128fdfe403e6',
#   '25ca610f-fcfe-4c4a-a41f-f646daa79e49',
#   'ae40c075-113b-46d8-af5e-4bddeeba2a6e',
#   '96ffc0e7-b50a-4992-8215-792adcc712c1',
#   'd5e67ab6-d954-4e42-8566-0c23a75bed12',
#   'f5bc3ca9-9d0c-4f8b-900a-588bea99ee45',
#   '4a60e987-d253-464e-ad9d-1319b34ae314',
#   'ffbd156f-1110-4c31-9695-11a8ac5df550',
#   'd17a4f82-92c1-4a50-8731-b8c6cef9e27c',
#   'b5e43b65-aafa-44d4-a199-e7eeb4c24625',
#   '5326a7b6-5c7d-454b-b809-d23de48873b2',
#   '23dcd3c6-8633-4eb3-a423-77fd9d849e89',
#   '615576a5-b22d-4090-b8c7-98cee2084900',
#   'c955b626-cd98-4a80-bbc5-755996292d4d',
#   'd62b0ec5-051c-4586-bb81-e9ea00ed11f6',
#   'bf5f9568-1d42-47a6-af4f-88d58b6711c4',
#   '62f7958a-478d-4b9e-89a0-cdfb214bb407',
#   '16a6fe12-2f88-4eef-af3e-293d40c3880e',
#   '59aab432-582c-473e-94f4-d69cdb9e4a17',
#   '75a18911-7d71-475a-963d-eda9c0094f1f',
#   '50a65913-243a-4cf3-a7e5-d3834ddcddeb',
#   '85c5aead-2fc0-46f7-9c12-fef314f299a3',
#   '4191381f-092a-4929-a2af-d553edd81484'],
#  'EuroStadium_Night_P': ['eacc54f9-06cf-49c0-a9b1-238aed98eca3',
#   '14ddbdfb-2d50-4da7-bfa2-9e26004b51fd',
#   '3fa21d60-ea28-40ab-bc08-007fd1b4bbe7',
#   'cd2aa4a9-a72f-4905-860b-ad358e4de7b9',
#   '9f7b20e9-a2d7-4578-b69d-3c3c480efd00',
#   '26f6b861-7bf8-4606-9e41-630495178102',
#   '0c5ee496-bbc0-44b0-9d6b-1fae67fa12fe',
#   'a393830f-58a3-4764-96c1-5be400e76f56',
#   'e68d1fa8-c755-4ee7-ae24-879e83d1f9e2',
#   '2d30336d-225c-4ada-9c4e-2075f8e67f94',
#   'c08d92f8-187b-42a7-8023-e079b1a80e43',
#   '25ea48bb-d514-4944-979b-7ca624d77f97',
#   'f6457f18-6e90-42e1-b4de-d115242ff4bb',
#   'a799ee86-e047-4087-af3b-3dcc855ec6f7',
#   'bdb149d8-9d68-4cd9-8fee-3e730cc118a7',
#   '7f7fd5ca-e21b-4b71-a256-bd7c4cdae46f',
#   '4629d801-8028-4f9b-8452-8146f0d250b5',
#   'f8bbaa0a-8a2f-444e-adad-fba3fc69675a',
#   '91c07960-a340-4b7a-ad9a-b481d869a634',
#   '8ca4206c-8a32-4c76-9483-b1013a3f11d1',
#   '34573049-895b-43f3-b553-97fb70018539',
#   'f3fd416f-3649-4aba-934f-249985881aa1',
#   '4f3afebe-6bb2-448b-b764-5e98d4ad932a',
#   'c4d6f6ed-ff57-40d6-83a3-871efa688fae',
#   'eb269f59-8108-44e3-9e2b-72ddec29cd76',
#   '16749bf5-b335-455e-bd64-22cd1db6a6b4',
#   '828eef23-1658-4861-a9c5-c9ed1aecf8fe',
#   '8ff1196c-7005-44c4-9f99-9dd3cbe476af',
#   'f0de6852-9d66-4df6-9a07-78e6724afd94',
#   '40cbf724-2b19-4307-bd8b-0b7355808ea6',
#   '67351ef9-3f0e-42ac-800e-1eefdbafb688',
#   '2ccde8c3-c118-443c-a6a1-9424c3baafc0',
#   'f666f10e-7c7c-4b6f-a21f-fdca68175eb7',
#   'fe71cb21-4af5-4eb9-a3d0-78529e5b19fe',
#   '0931d6c8-1f42-4f81-9c30-e954b213dff4',
#   '3464f57d-71aa-4eb5-a381-ea7553b3b81b',
#   '52bf3a0a-2f1f-439d-b906-d91925463c52',
#   'f44dde80-e058-47eb-9df6-19af401b122d',
#   'd5a20790-eb53-46f8-aac0-1482465d8fc7',
#   '8f09107d-4fdc-401a-950a-3b8ab6cf4c82',
#   '928b8dd4-b92b-49d4-b4cc-b4e49f0145d0',
#   '4d6e1dd1-d996-4750-8b41-627707d70577',
#   '9bb8a497-7026-47da-b89c-e46cb2bda4b7',
#   '03adfea8-4b43-4af5-9c8e-1e4b405f2ddd',
#   '69ee1052-d39f-4aab-921e-2fefb529962d']}

# %% [markdown]
# Let's verify we covered all the replays in our dataset:

# %%
count = 0
for key in map_to_replay_ids:
    count+= len(map_to_replay_ids[key])
count
# Out:
# 192

# %%
len(replays)
# Out:
# 192

# %% [markdown]
# These numbers match, so we're good.

# %% [markdown]
# Now, for each unique map name, we can randomly select a replay played on that map.

# %%
import random

random.seed(123)

sample_replay_list = []
for map_name in map_to_replay_ids:
    sample_replay_list.append(random.choice(map_to_replay_ids[map_name]))

sample_replay_list
# Out:
# ['960a9f35-821d-4c43-8c94-2d52697ecdeb',
#  'cb2c9df7-ca13-4e2c-979e-e61b9c6f4b96',
#  'd1b3c0c8-466e-4855-89b5-793b3a127ca5',
#  '186752c5-2adf-4a89-a9c4-333e967d7df9',
#  '73e0d71a-4325-4461-92a8-487445b75cc4',
#  'd06ce16e-a69a-4410-bfb8-554aa2a9f6da',
#  '0c5ee496-bbc0-44b0-9d6b-1fae67fa12fe']

# %% [markdown]
# Perfect, now we have a list of replays to inspect that covers all possible maps.

# %% [markdown]
# Let's look at the first replay in this list.

# %%
replay0_id = sample_replay_list[0]
replay0 = replays.load_replay(replay0_id)
replay0.frames.shape
# Out:
# (3187, 161)

# %%
replay0.goals
# Out:
# [{'PlayerName': 'M0nkey M00n', 'PlayerTeam': 0, 'frame': 2983},
#  {'PlayerName': 'ExoTiiK', 'PlayerTeam': 0, 'frame': 3889},
#  {'PlayerName': 'ExoTiiK', 'PlayerTeam': 0, 'frame': 5332},
#  {'PlayerName': 'Atomic', 'PlayerTeam': 1, 'frame': 5866},
#  {'PlayerName': 'M0nkey M00n', 'PlayerTeam': 0, 'frame': 6748},
#  {'PlayerName': 'dralii', 'PlayerTeam': 0, 'frame': 8176},
#  {'PlayerName': 'BeastMode', 'PlayerTeam': 1, 'frame': 9110}]

# %% [markdown]
# There are a certain number of goals in this particular replay, so we should see enough distinct regions in the `replay0.frames` array corresponding to these goals (depending on whether there's overtime or not). Note that the frame number given in the above dictionary does not correspond to the same frame numbers that appear in the `replay0.frames` array, since those numbers are in terms of the *original* frame indices from the *raw* replay which we sub-sampled during parsing.

# %%
# all columns indicating whether ball is stationary at the origin
pos_cols = ['Ball - position x', 'Ball - position y']
vel_cols = ['Ball - linear velocity x', 'Ball - linear velocity y']
z_cols = ['Ball - position z', 'Ball - linear velocity z']
x_y_cols = pos_cols + vel_cols
relevant_cols = x_y_cols + z_cols

df_subset = replay0.frames[relevant_cols]
df_subset.shape
# Out:
# (3187, 6)

# %%
df_boolean = df_subset[x_y_cols] == 0.0
df_boolean.head()
# Out:
#    Ball - position x  Ball - position y  Ball - linear velocity x  \
# 0              False              False                     False
# 1              False              False                     False
# 2              False              False                     False
# 3              False              False                     False
# 4              False              False                     False
#
#    Ball - linear velocity y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False

# %%
df_true = df_boolean.all(axis=1)
kickoff_setup_frames = df_subset.loc[df_subset.index[df_true]]
kickoff_setup_frames
# Out:
#       Ball - position x  Ball - position y  Ball - linear velocity x  \
# 936                 0.0                0.0                       0.0
# 937                 0.0                0.0                       0.0
# 938                 0.0                0.0                       0.0
# 939                 0.0                0.0                       0.0
# 940                 0.0                0.0                       0.0
# ...                 ...                ...                       ...
# 2587                0.0                0.0                       0.0
# 2588                0.0                0.0                       0.0
# 2589                0.0                0.0                       0.0
# 2590                0.0                0.0                       0.0
# 2591                0.0                0.0                       0.0
#
#       Ball - linear velocity y  Ball - position z  Ball - linear velocity z
# 936                        0.0          99.529999                -32.459999
# 937                        0.0          92.750000                -97.209999
# 938                        0.0          92.750000                  0.000000
# 939                        0.0          92.750000                  0.000000
# 940                        0.0          92.750000                  0.000000
# ...                        ...                ...                       ...
# 2587                       0.0          92.750000                  0.000000
# 2588                       0.0          92.750000                  0.000000
# 2589                       0.0          92.750000                  0.000000
# 2590                       0.0          92.750000                  0.000000
# 2591                       0.0          92.750000                  0.000000
#
# [149 rows x 6 columns]

# %% [markdown]
# At this point, `kickoff_setup_frames` is a `DataFrame` containing the rows where the ball's x- and y-coordinates are both 0.0 *and* its linear velocity in x and y is also 0.0. This physical condition is what we can use to determine whether the game is in a kickoff setup state or not, with the ball sitting motionless at the center of the field and the players sitting still in some configuration waiting for the kickoff.
#
# One might notice that `Ball - position z` is never equal to `0.0`, but is typically `92.75`(for these frames) and occasionally is a little higher; moreover, for the rows where `Ball - position z > 92.75`, we have that `Ball - linear velocity z` is nonzero. The z-coordinate of `92.75` is explained by the radius of the ball and the fact that its coordinates are the coordinates for its center. The nonzero values of the z-component of linear velocity and the values of the ball's z-coordinates greater than its radius are explained by the fact when the game resets to the kickoff setup configuration, it places the ball (and each of the players' cars) ever so slightly above the ground so that they have a subtle drop-in effect.
#
# Thus, we can't filter out rows where the z-coordinate of either the position or linear velocity of the ball are equal to zero. This observation motivates the kickoff-setup filtering conditions as being those rows where the ball's x- and y-coordinates in both position *and* linear velocity are zero.

# %% [markdown]
# The last thing to do is to count the number of continuous frame ranges satisfying these conditions and correspond this count with the number of goals scored and the presence of overtime in the replay.

# %%
cts_frame_ranges = []
length = len(kickoff_setup_frames)
i = 0
for index in kickoff_setup_frames.index:
    if i == 0:
        start = index
    elif index != kickoff_setup_frames.index[i-1] + 1:
        cts_frame_ranges.append((start, int(kickoff_setup_frames.index[i-1])))
        start = index
    i+=1
cts_frame_ranges.append((start, int(kickoff_setup_frames.index[i-1])))
cts_frame_ranges
# Out:
# [(936, 957),
#  (1169, 1189),
#  (1583, 1604),
#  (1695, 1715),
#  (1921, 1941),
#  (2329, 2349),
#  (2571, 2591)]

# %%
len(cts_frame_ranges)
# Out:
# 7

# %% [markdown]
# Finally, we need to repeat this for each of the replays in `sample_replay_list`. For simplicity, we should wrap the above checks in a reusable function that we can easily apply to any given replay.
